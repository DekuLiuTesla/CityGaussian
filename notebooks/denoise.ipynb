# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../outputs/citygs2d_mc_street_lnorm4_wo_vast_sep_depth_rgb_only_norm_ubd1e1_no_trim/test/epoch=8-step=30000/0138.png.png')
# remove pepper noise with median filter
median = cv2.medianBlur(img, 3)
# save image
cv2.imwrite('median.png', median)

plt.figure(figsize=(10, 10))
plt.imshow(median)
